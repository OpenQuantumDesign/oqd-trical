# %% [markdown]
# ## Imports

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
from oqd_core.interface.atomic import (
    AtomicCircuit,
    Beam,
    Ion,
    Level,
    Phonon,
    Pulse,
    SequentialProtocol,
    System,
    Transition,
)

from oqd_trical.backend.qutip.base import QutipBackend

# %%
matplotlib.rcParams["figure.figsize"] = (12, 8)
matplotlib.rcParams["font.size"] = 20
matplotlib.rcParams["mathtext.fontset"] = "stix"
matplotlib.rcParams["font.family"] = "STIXGeneral"

# %% [markdown]
# ## Atomic Circuit

# %%
downstate = Level(
    principal=6,
    spin=1 / 2,
    orbital=0,
    nuclear=1 / 2,
    spin_orbital=1 / 2,
    spin_orbital_nuclear=0,
    spin_orbital_nuclear_magnetization=0,
    energy=2 * np.pi * 0,
    label="q0",
)
estate = Level(
    principal=5,
    spin=1 / 2,
    orbital=1,
    nuclear=1 / 2,
    spin_orbital=1 / 2,
    spin_orbital_nuclear=1,
    spin_orbital_nuclear_magnetization=-1,
    energy=2 * np.pi * 100,
    label="e0",
)

transitions = [
    Transition(
        level1=downstate, level2=estate, einsteinA=1, multipole="E1", label="q0->e0"
    ),
]

Yb171 = Ion(
    mass=171,
    charge=1,
    position=[0, 0, 0],
    levels=[downstate, estate],
    transitions=transitions,
)

COM_x = Phonon(energy=2 * np.pi * 1, eigenvector=[1, 0, 0])

system = System(
    ions=[
        Yb171,
    ],
    modes=[
        COM_x,
    ],
)

beam = Beam(
    transition=transitions[0],
    rabi=2 * np.pi * 0.1,
    detuning=0,
    phase=0,
    polarization=[0, 1, 0],
    wavevector=[1, 0, 0],
    target=0,
)

beam2 = Beam(
    transition=transitions[0],
    rabi=2 * np.pi * 0.1,
    detuning=0,
    phase=np.pi,
    polarization=[0, 1, 0],
    wavevector=[1, 0, 0],
    target=0,
)

T = 10
step = 0.4

protocol = SequentialProtocol(
    sequence=[
        Pulse(beam=beam, duration=step)
        if i % 2 == 0
        else Pulse(beam=beam2, duration=step)
        for i in range(np.ceil(T // step).astype(int))
    ]
)

circuit = AtomicCircuit(system=system, protocol=protocol)

# %% [markdown]
# ### Serialization & Deserialization

# %%
import json

circuit_json = circuit.model_dump_json()
circuit_json = json.dumps(json.loads(circuit_json), indent=2)

with open("9b_example_floquet_fast.json", "w") as f:
    f.write(circuit_json)

# %%
with open("9b_example_floquet_fast.json", "r") as f:
    circuit_json = f.read()

assert AtomicCircuit.model_validate_json(circuit_json) == circuit

# %% [markdown]
# ## Qutip Intepreter

# %%
backend = QutipBackend(solver_options=dict(progress_bar=True))

fock_cutoff = 10
experiment, hilbert_space = backend.compile(circuit, fock_cutoff)

# %% [markdown]
# ### Results

# %%
result = backend.run(
    experiment,
    hilbert_space=hilbert_space,
    timestep=1e-2,
)
# Out:
# 10.3%. Run time:   0.31s. Est. time left: 00:00:00:02
# 20.5%. Run time:   0.63s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.06s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.48s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.92s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.40s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.85s. Est. time left: 00:00:00:01
# 82.1%. Run time:   3.32s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.77s. Est. time left: 00:00:00:00
# 100.0%. Run time:   4.10s. Est. time left: 00:00:00:00
# Total run time:   4.11s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.76s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.13s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.50s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.87s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.23s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.60s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.98s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.35s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.62s. Est. time left: 00:00:00:00
# Total run time:   3.62s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.73s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.10s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.46s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.82s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.17s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.52s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.88s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.23s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.49s. Est. time left: 00:00:00:00
# Total run time:   3.49s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.75s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.11s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.47s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.82s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.23s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.62s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.98s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.34s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.61s. Est. time left: 00:00:00:00
# Total run time:   3.61s
# 10.3%. Run time:   0.38s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.77s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.14s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.51s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.86s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.21s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.57s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.93s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.30s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.59s. Est. time left: 00:00:00:00
# Total run time:   3.59s
# 10.3%. Run time:   0.43s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.83s. Est. time left: 00:00:00:03
# 30.8%. Run time:   1.23s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.59s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.95s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.32s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.68s. Est. time left: 00:00:00:01
# 82.1%. Run time:   3.03s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.39s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.67s. Est. time left: 00:00:00:00
# Total run time:   3.67s
# 10.3%. Run time:   0.38s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.74s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.08s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.43s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.77s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.12s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.46s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.81s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.15s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.41s. Est. time left: 00:00:00:00
# Total run time:   3.41s
# 10.3%. Run time:   0.38s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.74s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.09s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.44s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.80s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.15s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.53s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.90s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.25s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.53s. Est. time left: 00:00:00:00
# Total run time:   3.53s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.75s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.10s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.45s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.80s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.14s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.48s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.83s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.17s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.43s. Est. time left: 00:00:00:00
# Total run time:   3.43s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.75s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.09s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.44s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.78s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.13s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.51s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.87s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.22s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.50s. Est. time left: 00:00:00:00
# Total run time:   3.50s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.76s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.11s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.49s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.85s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.20s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.57s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.93s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.28s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.59s. Est. time left: 00:00:00:00
# Total run time:   3.59s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.77s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.13s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.60s. Est. time left: 00:00:00:02
# 51.3%. Run time:   2.04s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.49s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.87s. Est. time left: 00:00:00:01
# 82.1%. Run time:   3.36s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.81s. Est. time left: 00:00:00:00
# 100.0%. Run time:   4.11s. Est. time left: 00:00:00:00
# Total run time:   4.11s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.74s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.09s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.44s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.79s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.13s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.49s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.84s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.19s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.47s. Est. time left: 00:00:00:00
# Total run time:   3.47s
# 10.3%. Run time:   0.41s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.77s. Est. time left: 00:00:00:03
# 30.8%. Run time:   1.15s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.51s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.89s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.25s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.61s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.97s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.34s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.61s. Est. time left: 00:00:00:00
# Total run time:   3.61s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.76s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.10s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.46s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.85s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.25s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.59s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.93s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.27s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.53s. Est. time left: 00:00:00:00
# Total run time:   3.53s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.82s. Est. time left: 00:00:00:03
# 30.8%. Run time:   1.27s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.76s. Est. time left: 00:00:00:02
# 51.3%. Run time:   2.16s. Est. time left: 00:00:00:02
# 61.5%. Run time:   2.52s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.89s. Est. time left: 00:00:00:01
# 82.1%. Run time:   3.25s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.61s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.90s. Est. time left: 00:00:00:00
# Total run time:   3.90s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.74s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.09s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.44s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.78s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.13s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.48s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.82s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.17s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.44s. Est. time left: 00:00:00:00
# Total run time:   3.44s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.77s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.15s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.57s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.97s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.32s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.68s. Est. time left: 00:00:00:01
# 82.1%. Run time:   3.03s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.39s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.65s. Est. time left: 00:00:00:00
# Total run time:   3.65s
# 10.3%. Run time:   0.33s. Est. time left: 00:00:00:02
# 20.5%. Run time:   0.63s. Est. time left: 00:00:00:02
# 30.8%. Run time:   0.93s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.23s. Est. time left: 00:00:00:01
# 51.3%. Run time:   1.53s. Est. time left: 00:00:00:01
# 61.5%. Run time:   1.82s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.12s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.42s. Est. time left: 00:00:00:00
# 92.3%. Run time:   2.72s. Est. time left: 00:00:00:00
# 100.0%. Run time:   2.94s. Est. time left: 00:00:00:00
# Total run time:   2.94s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.75s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.11s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.46s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.83s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.20s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.55s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.91s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.26s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.55s. Est. time left: 00:00:00:00
# Total run time:   3.56s
# 10.3%. Run time:   0.39s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.75s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.09s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.47s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.83s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.18s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.53s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.88s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.24s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.51s. Est. time left: 00:00:00:00
# Total run time:   3.51s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.75s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.12s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.48s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.83s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.19s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.54s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.91s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.28s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.59s. Est. time left: 00:00:00:00
# Total run time:   3.59s
# 10.3%. Run time:   0.43s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.77s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.12s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.46s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.80s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.15s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.49s. Est. time left: 00:00:00:00
# 82.1%. Run time:   2.83s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.17s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.43s. Est. time left: 00:00:00:00
# Total run time:   3.43s
# 10.3%. Run time:   0.40s. Est. time left: 00:00:00:03
# 20.5%. Run time:   0.77s. Est. time left: 00:00:00:02
# 30.8%. Run time:   1.14s. Est. time left: 00:00:00:02
# 41.0%. Run time:   1.53s. Est. time left: 00:00:00:02
# 51.3%. Run time:   1.88s. Est. time left: 00:00:00:01
# 61.5%. Run time:   2.24s. Est. time left: 00:00:00:01
# 71.8%. Run time:   2.61s. Est. time left: 00:00:00:01
# 82.1%. Run time:   2.98s. Est. time left: 00:00:00:00
# 92.3%. Run time:   3.35s. Est. time left: 00:00:00:00
# 100.0%. Run time:   3.63s. Est. time left: 00:00:00:00
# Total run time:   3.63s

# %%
k = slice(None, None, 1)

fig = plt.figure()

ax = fig.subplots(1, 1, sharex=True)

ax.plot(
    result["tspan"][k],
    [s.ptrace(0).diag()[:] for s in result["states"][k]],
    label=[rf"$P(|{i}\rangle)$" for i in range(2)],
)

ax.set_xlabel(r"$t$", labelpad=10)
ax.set_ylabel(r"$P(| \psi \rangle)$", labelpad=10)

ax.legend()

# %%
k = slice(None, None, 1)

fig = plt.figure()

ax = fig.subplots(1, 1, sharex=True)

ax.plot(
    result["tspan"][k],
    [s.ptrace(1).diag()[:] for s in result["states"][k]],
    label=[rf"$P(|n={i}\rangle)$" for i in range(10)],
)

ax.set_xlabel(r"$t$", labelpad=10)
ax.set_ylabel(r"$P(| \psi \rangle)$", labelpad=10)

ax.legend()
